# %% [markdown]
# <a href="https://colab.research.google.com/github/GustavoBcc71/testeColab/blob/main/Conhe%C3%A7a_o_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#include<iostream>
using namespace std;

int main() {

    cout << "Hello, World! " << endl;

}
# Out:
#   File "/tmp/ipykernel_31877/1247520314.py", line 2
#     using namespace std;
#           ^
# SyntaxError: invalid syntax
